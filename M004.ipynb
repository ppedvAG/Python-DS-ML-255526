# %% [markdown]
# ## Fehlerbehandlung mit Pandas
#
# Fehler in den Daten selbst beheben

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Data/PopulationDataFastFertig.csv", delimiter=",", thousands=",", decimal=".", index_col="Country")

# %%
data
# Out:
#                   Population YearlyChange  NetChange  Density  LandArea  \
# Country
# China             1439323776       0.39 %    5540090      153   9388211
# India             1380004385       0.99 %   13586631      464   2973190
# United States      331002651       0.59 %    1937734       36   9147420
# Indonesia          273523615       1.07 %    2898047      151   1811570
# Pakistan           220892340       2.00 %    4327022      287    770880
# ...                      ...          ...        ...      ...       ...
# Montserrat              4992       0.06 %          3       50       100
# Falkland Islands        3480       3.05 %        103        0     12170
# Niue                    1626       0.68 %         11        6       260
# Tokelau                 1357       1.27 %         17      136        10
# Vatican State            801       0.25 %          2     2003         0
#
#                   Migrants FertRate MedAge UrbanPopPct WorldSharePct
# Country
# China            -348399.0      1.7     38        61 %       18.47 %
# India            -532687.0      2.2     28        35 %       17.70 %
# United States     954806.0      1.8     38        83 %        4.25 %
# Indonesia         -98955.0      2.3     30        56 %        3.51 %
# Pakistan         -233379.0      3.6     23        35 %        2.83 %
# ...                    ...      ...    ...         ...           ...
# Montserrat             NaN     N.A.   N.A.        10 %        0.00 %
# Falkland Islands       NaN     N.A.   N.A.        66 %        0.00 %
# Niue                   NaN     N.A.   N.A.        46 %        0.00 %
# Tokelau                NaN     N.A.   N.A.         0 %        0.00 %
# Vatican State          NaN     N.A.   N.A.        N.A.        0.00 %
#
# [235 rows x 10 columns]

# %% [markdown]
# ### Probleme mit dem Datenset
#
# - NaN
# - N.A.
# - Prozentzeichen
# - Datentypen (effiziente Typen)

# %% [markdown]
# #### NaN
#
# isnull(), notnull()
#
# isna(), notna()

# %%
data.notna()
# Out:
#                   Population  YearlyChange  NetChange  Density  LandArea  \
# Country
# China                   True          True       True     True      True
# India                   True          True       True     True      True
# United States           True          True       True     True      True
# Indonesia               True          True       True     True      True
# Pakistan                True          True       True     True      True
# ...                      ...           ...        ...      ...       ...
# Montserrat              True          True       True     True      True
# Falkland Islands        True          True       True     True      True
# Niue                    True          True       True     True      True
# Tokelau                 True          True       True     True      True
# Vatican State           True          True       True     True      True
#
#                   Migrants  FertRate  MedAge  UrbanPopPct  WorldSharePct
# Country
# China                 True      True    True         True           True
# India                 True      True    True         True           True
# United States         True      True    True         True           True
# Indonesia             True      True    True         True           True
# Pakistan              True      True    True         True           True
# ...                    ...       ...     ...          ...            ...
# Montserrat           False      True    True         True           True
# Falkland Islands     False      True    True         True           True
# Niue                 False      True    True         True           True
# Tokelau              False      True    True         True           True
# Vatican State        False      True    True         True           True
#
# [235 rows x 10 columns]

# %%
data["Migrants"].isna()
# Out:
# Country
# China               False
# India               False
# United States       False
# Indonesia           False
# Pakistan            False
#                     ...
# Montserrat           True
# Falkland Islands     True
# Niue                 True
# Tokelau              True
# Vatican State        True
# Name: Migrants, Length: 235, dtype: bool

# %%
x = data["Migrants"].isna()

# %%
data["Migrants"][x]
# Out:
# Country
# Isle of Man                NaN
# Andorra                    NaN
# Dominica                   NaN
# Cayman Islands             NaN
# Bermuda                    NaN
# Marshall Islands           NaN
# Northern Mariana Islands   NaN
# Greenland                  NaN
# American Samoa             NaN
# Saint Kitts & Nevis        NaN
# Faeroe Islands             NaN
# Sint Maarten               NaN
# Monaco                     NaN
# Turks and Caicos           NaN
# Saint Martin               NaN
# Liechtenstein              NaN
# San Marino                 NaN
# Gibraltar                  NaN
# British Virgin Islands     NaN
# Caribbean Netherlands      NaN
# Palau                      NaN
# Cook Islands               NaN
# Anguilla                   NaN
# Tuvalu                     NaN
# Wallis & Futuna            NaN
# Nauru                      NaN
# Saint Barthelemy           NaN
# Saint Helena               NaN
# Saint Pierre & Miquelon    NaN
# Montserrat                 NaN
# Falkland Islands           NaN
# Niue                       NaN
# Tokelau                    NaN
# Vatican State              NaN
# Name: Migrants, dtype: float64

# %%
data.isna().value_counts()
# Out:
# Population  YearlyChange  NetChange  Density  LandArea  Migrants  FertRate  MedAge  UrbanPopPct  WorldSharePct
# False       False         False      False    False     False     False     False   False        False            201
#                                                         True      False     False   False        False             34
# Name: count, dtype: int64

# %%
data["Migrants"][x] = 0  # Funktioniert, sollte aber per loc gemacht werden
# Out:
# C:\Users\lk3\AppData\Local\Temp\ipykernel_7064\810017183.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data["Migrants"][x] = 0  # Funktioniert, sollte aber per loc gemacht werden
# C:\Users\lk3\AppData\Local\Temp\ipykernel_7064\810017183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Migrants"][x] = 0  # Funktioniert, sollte aber per loc gemacht werden

# %%
data.loc[x, "Migrants"] = 0

# %%
data
# Out:
#                   Population YearlyChange  NetChange  Density  LandArea  \
# Country
# China             1439323776       0.39 %    5540090      153   9388211
# India             1380004385       0.99 %   13586631      464   2973190
# United States      331002651       0.59 %    1937734       36   9147420
# Indonesia          273523615       1.07 %    2898047      151   1811570
# Pakistan           220892340       2.00 %    4327022      287    770880
# ...                      ...          ...        ...      ...       ...
# Montserrat              4992       0.06 %          3       50       100
# Falkland Islands        3480       3.05 %        103        0     12170
# Niue                    1626       0.68 %         11        6       260
# Tokelau                 1357       1.27 %         17      136        10
# Vatican State            801       0.25 %          2     2003         0
#
#                   Migrants FertRate MedAge UrbanPopPct WorldSharePct
# Country
# China            -348399.0      1.7     38        61 %       18.47 %
# India            -532687.0      2.2     28        35 %       17.70 %
# United States     954806.0      1.8     38        83 %        4.25 %
# Indonesia         -98955.0      2.3     30        56 %        3.51 %
# Pakistan         -233379.0      3.6     23        35 %        2.83 %
# ...                    ...      ...    ...         ...           ...
# Montserrat             0.0     N.A.   N.A.        10 %        0.00 %
# Falkland Islands       0.0     N.A.   N.A.        66 %        0.00 %
# Niue                   0.0     N.A.   N.A.        46 %        0.00 %
# Tokelau                0.0     N.A.   N.A.         0 %        0.00 %
# Vatican State          0.0     N.A.   N.A.        N.A.        0.00 %
#
# [235 rows x 10 columns]

# %% [markdown]
# #### dropna(), fillna()
#
# dropna(): Wirft alle Zeilen mit NaN Werten weg
#
# fillna(): Füllt NaN Werte mit den vorherigen/nachfolgenden Werten auf

# %%
data.fillna(method="ffill")
# Out:
# C:\Users\lk3\AppData\Local\Temp\ipykernel_7064\2321864255.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method="ffill")
#                   Population YearlyChange  NetChange  Density  LandArea  \
# Country
# China             1439323776       0.39 %    5540090      153   9388211
# India             1380004385       0.99 %   13586631      464   2973190
# United States      331002651       0.59 %    1937734       36   9147420
# Indonesia          273523615       1.07 %    2898047      151   1811570
# Pakistan           220892340       2.00 %    4327022      287    770880
# ...                      ...          ...        ...      ...       ...
# Montserrat              4992       0.06 %          3       50       100
# Falkland Islands        3480       3.05 %        103        0     12170
# Niue                    1626       0.68 %         11        6       260
# Tokelau                 1357       1.27 %         17      136        10
# Vatican State            801       0.25 %          2     2003         0
#
#                   Migrants FertRate MedAge UrbanPopPct WorldSharePct
# Country
# China            -348399.0      1.7     38        61 %       18.47 %
# India            -532687.0      2.2     28        35 %       17.70 %
# United States     954806.0      1.8     38        83 %        4.25 %
# Indonesia         -98955.0      2.3     30        56 %        3.51 %
# Pakistan         -233379.0      3.6     23        35 %        2.83 %
# ...                    ...      ...    ...         ...           ...
# Montserrat             0.0     N.A.   N.A.        10 %        0.00 %
# Falkland Islands       0.0     N.A.   N.A.        66 %        0.00 %
# Niue                   0.0     N.A.   N.A.        46 %        0.00 %
# Tokelau                0.0     N.A.   N.A.         0 %        0.00 %
# Vatican State          0.0     N.A.   N.A.        N.A.        0.00 %
#
# [235 rows x 10 columns]

# %%
data.ffill(inplace=True)

# %% [markdown]
# ### N.A.
#
# Keine automatische Lösung -> manuell
#
# Via. String Replace

# %%
data == "N.A."
# Out:
#                   Population  YearlyChange  NetChange  Density  LandArea  \
# Country
# China                  False         False      False    False     False
# India                  False         False      False    False     False
# United States          False         False      False    False     False
# Indonesia              False         False      False    False     False
# Pakistan               False         False      False    False     False
# ...                      ...           ...        ...      ...       ...
# Montserrat             False         False      False    False     False
# Falkland Islands       False         False      False    False     False
# Niue                   False         False      False    False     False
# Tokelau                False         False      False    False     False
# Vatican State          False         False      False    False     False
#
#                   Migrants  FertRate  MedAge  UrbanPopPct  WorldSharePct
# Country
# China                False     False   False        False          False
# India                False     False   False        False          False
# United States        False     False   False        False          False
# Indonesia            False     False   False        False          False
# Pakistan             False     False   False        False          False
# ...                    ...       ...     ...          ...            ...
# Montserrat           False      True    True        False          False
# Falkland Islands     False      True    True        False          False
# Niue                 False      True    True        False          False
# Tokelau              False      True    True        False          False
# Vatican State        False      True    True         True          False
#
# [235 rows x 10 columns]

# %%
(data == "N.A.").value_counts()
# Out:
# Population  YearlyChange  NetChange  Density  LandArea  Migrants  FertRate  MedAge  UrbanPopPct  WorldSharePct
# False       False         False      False    False     False     False     False   False        False            194
#                                                                   True      True    False        False             28
#                                                                   False     False   True         False              7
#                                                                   True      True    True         False              6
# Name: count, dtype: int64

# %% [markdown]
# Spaltenweise machen -> Spalten durchgehen, prüfen wo N.A. Werte sich befinden, mit loc austauschen

# %%
for col in data.columns:
    x = data[col] == "N.A."
    data.loc[x, col] = 0

# %%
data
# Out:
#                   Population YearlyChange  NetChange  Density  LandArea  \
# Country
# China             1439323776       0.39 %    5540090      153   9388211
# India             1380004385       0.99 %   13586631      464   2973190
# United States      331002651       0.59 %    1937734       36   9147420
# Indonesia          273523615       1.07 %    2898047      151   1811570
# Pakistan           220892340       2.00 %    4327022      287    770880
# ...                      ...          ...        ...      ...       ...
# Montserrat              4992       0.06 %          3       50       100
# Falkland Islands        3480       3.05 %        103        0     12170
# Niue                    1626       0.68 %         11        6       260
# Tokelau                 1357       1.27 %         17      136        10
# Vatican State            801       0.25 %          2     2003         0
#
#                   Migrants FertRate MedAge UrbanPopPct WorldSharePct
# Country
# China            -348399.0      1.7     38        61 %       18.47 %
# India            -532687.0      2.2     28        35 %       17.70 %
# United States     954806.0      1.8     38        83 %        4.25 %
# Indonesia         -98955.0      2.3     30        56 %        3.51 %
# Pakistan         -233379.0      3.6     23        35 %        2.83 %
# ...                    ...      ...    ...         ...           ...
# Montserrat             0.0        0      0        10 %        0.00 %
# Falkland Islands       0.0        0      0        66 %        0.00 %
# Niue                   0.0        0      0        46 %        0.00 %
# Tokelau                0.0        0      0         0 %        0.00 %
# Vatican State          0.0        0      0           0        0.00 %
#
# [235 rows x 10 columns]

# %%
def fixNA(colName: str, newValue):
    x = data[colName] == "N.A."
    data.loc[x, colName] = newValue

# %%
for col in data.columns:
    fixNA(col, 0)

# %% [markdown]
# ### Prozentzeichen
#
# Muss mithilfe von String Replace gemacht werden

# %%
data["YearlyChange"].replace(" %", "", regex=True)
# Out:
# Country
# China               0.39
# India               0.99
# United States       0.59
# Indonesia           1.07
# Pakistan            2.00
#                     ...
# Montserrat          0.06
# Falkland Islands    3.05
# Niue                0.68
# Tokelau             1.27
# Vatican State       0.25
# Name: YearlyChange, Length: 235, dtype: object

# %%
data["YearlyChange"] = data["YearlyChange"].replace(" %", "", regex=True)

# %%
data
# Out:
#                   Population YearlyChange  NetChange  Density  LandArea  \
# Country
# China             1439323776         0.39    5540090      153   9388211
# India             1380004385         0.99   13586631      464   2973190
# United States      331002651         0.59    1937734       36   9147420
# Indonesia          273523615         1.07    2898047      151   1811570
# Pakistan           220892340         2.00    4327022      287    770880
# ...                      ...          ...        ...      ...       ...
# Montserrat              4992         0.06          3       50       100
# Falkland Islands        3480         3.05        103        0     12170
# Niue                    1626         0.68         11        6       260
# Tokelau                 1357         1.27         17      136        10
# Vatican State            801         0.25          2     2003         0
#
#                   Migrants FertRate MedAge UrbanPopPct WorldSharePct
# Country
# China            -348399.0      1.7     38        61 %       18.47 %
# India            -532687.0      2.2     28        35 %       17.70 %
# United States     954806.0      1.8     38        83 %        4.25 %
# Indonesia         -98955.0      2.3     30        56 %        3.51 %
# Pakistan         -233379.0      3.6     23        35 %        2.83 %
# ...                    ...      ...    ...         ...           ...
# Montserrat             0.0        0      0        10 %        0.00 %
# Falkland Islands       0.0        0      0        66 %        0.00 %
# Niue                   0.0        0      0        46 %        0.00 %
# Tokelau                0.0        0      0         0 %        0.00 %
# Vatican State          0.0        0      0           0        0.00 %
#
# [235 rows x 10 columns]

# %%
def fixPct(colName):
    x = data[colName].replace(" %", "", regex=True)
    data[colName] = x

# %%
for col in data.columns:
    fixPct(col)

# %%
data
# Out:
#                   Population YearlyChange  NetChange  Density  LandArea  \
# Country
# China             1439323776         0.39    5540090      153   9388211
# India             1380004385         0.99   13586631      464   2973190
# United States      331002651         0.59    1937734       36   9147420
# Indonesia          273523615         1.07    2898047      151   1811570
# Pakistan           220892340         2.00    4327022      287    770880
# ...                      ...          ...        ...      ...       ...
# Montserrat              4992         0.06          3       50       100
# Falkland Islands        3480         3.05        103        0     12170
# Niue                    1626         0.68         11        6       260
# Tokelau                 1357         1.27         17      136        10
# Vatican State            801         0.25          2     2003         0
#
#                   Migrants FertRate MedAge UrbanPopPct WorldSharePct
# Country
# China            -348399.0      1.7     38          61         18.47
# India            -532687.0      2.2     28          35         17.70
# United States     954806.0      1.8     38          83          4.25
# Indonesia         -98955.0      2.3     30          56          3.51
# Pakistan         -233379.0      3.6     23          35          2.83
# ...                    ...      ...    ...         ...           ...
# Montserrat             0.0        0      0          10          0.00
# Falkland Islands       0.0        0      0          66          0.00
# Niue                   0.0        0      0          46          0.00
# Tokelau                0.0        0      0           0          0.00
# Vatican State          0.0        0      0           0          0.00
#
# [235 rows x 10 columns]

# %% [markdown]
# ### Datentypen
#
# Bei den vorherigen Änderungen wurden die Typen nicht angepasst
#
# -> Manuell

# %%
data.convert_dtypes().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Vatican State
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Population     235 non-null    Int64
#  1   YearlyChange   235 non-null    string
#  2   NetChange      235 non-null    Int64
#  3   Density        235 non-null    Int64
#  4   LandArea       235 non-null    Int64
#  5   Migrants       235 non-null    Int64
#  6   FertRate       235 non-null    object
#  7   MedAge         235 non-null    object
#  8   UrbanPopPct    235 non-null    object
#  9   WorldSharePct  235 non-null    string
# dtypes: Int64(5), object(3), string(2)
# memory usage: 29.4+ KB

# %%
data["Population"] = data["Population"].astype(np.int32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Vatican State
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Population     235 non-null    int32
#  1   YearlyChange   235 non-null    object
#  2   NetChange      235 non-null    int64
#  3   Density        235 non-null    int64
#  4   LandArea       235 non-null    int64
#  5   Migrants       235 non-null    float64
#  6   FertRate       235 non-null    object
#  7   MedAge         235 non-null    object
#  8   UrbanPopPct    235 non-null    object
#  9   WorldSharePct  235 non-null    object
# dtypes: float64(1), int32(1), int64(3), object(5)
# memory usage: 27.4+ KB

# %%
def fixType(colName, newType):
    data[colName] = data[colName].astype(newType)

# %%
fixType("YearlyChange", np.float32)

# %%
fixType("NetChange", np.int32)

# %%
fixType("Density", np.int16)

# %%
fixType("LandArea", np.int32)

# %%
fixType("Migrants", np.int32)

# %%
fixType("FertRate", np.float32)

# %%
fixType("MedAge", np.int8)

# %%
fixType("UrbanPopPct", np.int8)

# %%
fixType("WorldSharePct", np.float32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235 entries, China to Vatican State
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Population     235 non-null    int32
#  1   YearlyChange   235 non-null    float32
#  2   NetChange      235 non-null    int32
#  3   Density        235 non-null    int16
#  4   LandArea       235 non-null    int32
#  5   Migrants       235 non-null    int32
#  6   FertRate       235 non-null    float32
#  7   MedAge         235 non-null    int8
#  8   UrbanPopPct    235 non-null    int8
#  9   WorldSharePct  235 non-null    float32
# dtypes: float32(3), int16(1), int32(4), int8(2)
# memory usage: 17.3+ KB

# %%
17.3/27.4  # ~37% Speicherersparnis
# Out:
# 0.6313868613138687

# %%
for row in data["Population"]:
    try:
        x = int(row)
    except:
        print(f"Zeile kann nicht zu int konvertiert werden: {row}")
        
    try:
        x = float(row)
    except:
        print(f"Zeile kann nicht zu float konvertiert werden: {row}")
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
data.to_csv("Data/PopulationDataFertig.csv")
